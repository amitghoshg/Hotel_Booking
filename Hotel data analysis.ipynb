# %% [markdown]
# #### 1> Import library to connect Mongodb

# %%
from pymongo import MongoClient
import pandas as pd
import csv
import warnings
warnings.filterwarnings('ignore')

# %%
# MongoDB connection
client = MongoClient("mongodb://localhost:27017/")
db = client["Python_Data_Analysis"]
collection = db["Hotel Booking"]

# %%
# Create a cursor and load data in chunks
batch_size = 10000  # Tune based on available memory
cursor = collection.find({}, no_cursor_timeout=True).batch_size(batch_size)

# Accumulate data into DataFrame
dataframes = []

try:
    batch = []
    for doc in cursor:
        batch.append(doc)
        if len(batch) >= batch_size:
            df_batch = pd.DataFrame(batch)
            df_batch.drop(columns=['_id'], inplace=True, errors='ignore')  # Drop MongoDB internal ID
            dataframes.append(df_batch)
            batch = []
    
    # Process remaining docs
    if batch:
        df_batch = pd.DataFrame(batch)
        df_batch.drop(columns=['_id'], inplace=True, errors='ignore')
        dataframes.append(df_batch)

finally:
    cursor.close()
    client.close()

# Combine all batches into a single DataFrame
hotel_data = pd.concat(dataframes, ignore_index=True)

# %% [markdown]
# ####  2> Import Libraries for data analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hotel_data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotel_data.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status             name  \
# count        119390        119390             119390           119390
# unique            3             4                  3            81503
# top      No Deposit     Transient          Check-Out  Michael Johnson
# ...

# %%
for col in hotel_data.describe(include='object').columns:         # Print unique values for each categorical column
    print(col)
    print(hotel_data[col].unique())
    print('='*50)
# Out:
# hotel
# ['Resort Hotel' 'City Hotel']
# ...
# arrival_date_month
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# ...
# meal
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# ...
# country
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' nan 'ROU' 'NOR' 'OMN' 'ARG' 'POL'
#  'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS' 'EST'
#  'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX' 'MAR'
#  'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF' 'AGO'
#  'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN' 'JAM'
#  'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL' 'GGY'
#  'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL' 'SEN'
#  'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA' 'CUB'
#  'CMR' 'BIH' 'MUS' 'COM' 'SUR' 'UGA' 'BGR' 'CIV' 'JOR' 'SYR' 'SGP' 'BDI'
#  'SAU' 'VNM' 'PLW' 'QAT' 'EGY' 'PER' 'MLT' 'MWI' 'ECU' 'MDG' 'ISL' 'UZB'
# ...

# %%
hotel_data.isnull().sum()  # Check for missing values
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotel_data.drop(['company','agent'], axis =1, inplace = True)    # Dropeping columns with too many missing values
hotel_data.dropna(inplace =True)

# %%
hotel_data = hotel_data[hotel_data['adr']<5000]
hotel_data.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  118897.000000  118897.000000      118897.000000
# mean        0.371347     104.312018        2016.157657
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     161.000000        2017.000000
# max         1.000000     737.000000        2017.000000
# std         0.483167     106.903570           0.707462
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             118897.000000              118897.000000
# mean                  27.166674                  15.800802
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# 75%                   38.000000                  23.000000
# ...

# %% [markdown]
# #### 3> Data Analysis and Visualization

# %%
# Check cancelled and not cancelled percentage
cancelled_percentage = hotel_data["is_canceled"].value_counts(normalize=True)
print("Percentage of bookings not cancelled: {:.2f}%".format(cancelled_percentage[0] * 100))
print("Percentage of bookings cancelled: {:.2f}%".format(cancelled_percentage[1] * 100))
# Out:
# Percentage of bookings not cancelled: 62.87%
# Percentage of bookings cancelled: 37.13%

# %%
plt.figure(figsize = (8,4))
plt.title('Reservation Status',color = 'Blue',size = 20)
plt.bar(['Not cancelled (0)' , 'Cancelled (1)'],hotel_data['is_canceled'].value_counts(), edgecolor = 'k', width = 0.5)
plt.show()

# %%
# Set the background color of the figure
plt.figure(figsize=(8, 4))

# Create the countplot
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=hotel_data, palette = ["#F93D5F", "#3318CD"])

# Customize legend location
legend_labels, _ = ax1.get_legend_handles_labels()
ax1.legend(bbox_to_anchor=(1, 1))

# Set plot title and axis labels
plt.title('Reservation status in different hotels', size=20, color='Blue')
plt.xlabel('Hotel',color='Black')
plt.ylabel('Number of Reservations', color='Black')

# Customize legend labels
plt.legend(['Not Cancelled', 'Cancelled'])

# Show the plot
plt.show()

# %%
#checking the graph cancelation rate in percentage for Resort Hotel

resort_hotel = hotel_data[hotel_data['hotel'] == 'Resort Hotel']

print("Percentage of bookings not cancelled in Resort Hotel: {:.2f}%".format(resort_hotel['is_canceled'].value_counts(normalize=True)[0] * 100)) 
print("Percentage of bookings cancelled in Resort Hotel: {:.2f}%".format(resort_hotel['is_canceled'].value_counts(normalize=True)[1] * 100)) 
print('-'*70)

# checking the graph cancelation rate in percentage for City Hotel
city_hotel = hotel_data[hotel_data['hotel'] == 'City Hotel']
print("Percentage of bookings not cancelled in City Hotel: {:.2f}%".format(city_hotel['is_canceled'].value_counts(normalize=True)[0] * 100))
print("Percentage of bookings cancelled in City Hotel: {:.2f}%".format(city_hotel['is_canceled'].value_counts(normalize=True)[1] * 100))
# Out:
# Percentage of bookings not cancelled in Resort Hotel: 72.02%
# Percentage of bookings cancelled in Resort Hotel: 27.98%
# ----------------------------------------------------------------------
# Percentage of bookings not cancelled in City Hotel: 58.29%
# Percentage of bookings cancelled in City Hotel: 41.71%

# %%
resort_hotel = resort_hotel.groupby('reservation_status_date')[['adr']].mean()
city_hotel = city_hotel.groupby('reservation_status_date')[['adr']].mean()

# %%
plt.figure(figsize=(20,5))
plt.title('Average Daily Rate in City and Resort Hotel',color = 'blue', fontsize=20)
plt.plot(resort_hotel.index,resort_hotel['adr'],label = 'Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label = 'City Hotel')
plt.legend(fontsize=10)
plt.show()

# %%
hotel_data['month']=hotel_data['reservation_status_date'].dt.month
plt.figure(figsize=(20,5))
ax1 = sns.countplot(x='month', hue='is_canceled', data= hotel_data, palette = 'dark')
legend_lebels,_ = ax1.get_legend_handles_labels()
plt.title('Reservation Status Per Month', size = 20, color = 'Blue')
plt.xlabel('month')
plt.ylabel('Number of Reservation')
plt.legend(['Not Canceled','Canceld'])
plt.show()

# %%
plt.figure(figsize = (15,5))
plt.title('ADR per Month', fontsize = 20, color = 'Blue')
# Group by month and sum the ADR for canceled bookings
# data =df[df['is_canceled'] == 1].groupby('month')['adr'].sum().reset_index()

data = hotel_data[hotel_data['is_canceled'] == 1].groupby('month')['adr'].sum().reset_index()
sns.barplot(x='month', y='adr', data = data, palette='viridis')
plt.legend(fontsize = 20)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
cancelled_data = hotel_data[hotel_data['is_canceled'] == 1]
top_10_country = cancelled_data['country'].value_counts()[:10]

colors = plt.cm.tab10.colors

plt.figure(figsize=(8, 8))
plt.title('Top 10 countries with reservation canceled', color="blue", fontsize=20)
plt.pie(top_10_country, autopct='%.2f', labels=top_10_country.index, colors=colors)
plt.show()

# %%
hotel_data['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56402
# Offline TA/TO    24159
# Groups           19806
# Direct           12448
# Corporate         5111
# Complementary      734
# Aviation           237
# Name: count, dtype: int64

# %%
hotel_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.474377
# Offline TA/TO    0.203193
# Groups           0.166581
# Direct           0.104696
# Corporate        0.042987
# Complementary    0.006173
# Aviation         0.001993
# Name: proportion, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# market_segment
# Online TA        0.469696
# Groups           0.273985
# Offline TA/TO    0.187466
# Direct           0.043486
# Corporate        0.022151
# Complementary    0.002038
# Aviation         0.001178
# Name: proportion, dtype: float64

# %%
cancelled_df_adr= cancelled_data.groupby('reservation_status_date')[['adr']].mean()
cancelled_df_adr.reset_index(inplace=True)
cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

not_cancelled_data=hotel_data[hotel_data['is_canceled']==0]
not_cancelled_df_adr= not_cancelled_data.groupby('reservation_status_date')[['adr']].mean()
not_cancelled_df_adr.reset_index(inplace=True)
not_cancelled_df_adr.sort_values('reservation_status_date', inplace=True)

plt.figure(figsize=(20,6))
plt.title('Average Daily Rate', color="blue", fontsize=20)
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'], label = 'cancelled')
plt.legend()
plt.show()

# %%
cancelled_df_adr = cancelled_df_adr[(cancelled_df_adr['reservation_status_date']>'2016') & (cancelled_df_adr['reservation_status_date']<'2017-09')]

not_cancelled_df_adr = not_cancelled_df_adr[(not_cancelled_df_adr['reservation_status_date']>'2016') & (not_cancelled_df_adr['reservation_status_date']<'2017-09')]

# %%
plt.figure(figsize=(20,6))
plt.title('Average Daily Rate', fontsize = 20, color = 'Blue')
plt.plot(not_cancelled_df_adr['reservation_status_date'],not_cancelled_df_adr['adr'], label='not cancelled')
plt.plot(cancelled_df_adr['reservation_status_date'],cancelled_df_adr['adr'], label = 'cancelled')
plt.legend(fontsize = 15)
plt.show()
